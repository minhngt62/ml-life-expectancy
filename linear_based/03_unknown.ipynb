# %%
# Importing useful libraries that will be needed for this analysis

import pandas as pd
import numpy as np
from scipy.stats.mstats import winsorize
import IPython
import seaborn as sns
import matplotlib.pyplot as plt
from pandas_profiling import ProfileReport
from sklearn import linear_model

# %matplotlib inline

# %%
# !pip install optuna
# Out:
# Requirement already satisfied: optuna in c:\users\thu hien\anaconda3\lib\site-packages (2.10.0)
# Requirement already satisfied: numpy in c:\users\thu hien\appdata\roaming\python\python39\site-packages (from optuna) (1.20.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\thu hien\appdata\roaming\python\python39\site-packages (from optuna) (20.9)
# Requirement already satisfied: cliff in c:\users\thu hien\anaconda3\lib\site-packages (from optuna) (3.10.1)
# Requirement already satisfied: alembic in c:\users\thu hien\anaconda3\lib\site-packages (from optuna) (1.7.7)
# Requirement already satisfied: colorlog in c:\users\thu hien\anaconda3\lib\site-packages (from optuna) (6.6.0)
# Requirement already satisfied: cmaes>=0.8.2 in c:\users\thu hien\anaconda3\lib\site-packages (from optuna) (0.8.2)
# Requirement already satisfied: sqlalchemy>=1.1.0 in c:\users\thu hien\anaconda3\lib\site-packages (from optuna) (1.4.22)
# Requirement already satisfied: tqdm in c:\users\thu hien\anaconda3\lib\site-packages (from optuna) (4.62.3)
# Requirement already satisfied: PyYAML in c:\users\thu hien\anaconda3\lib\site-packages (from optuna) (6.0)
# Requirement already satisfied: scipy!=1.4.0 in c:\users\thu hien\appdata\roaming\python\python39\site-packages (from optuna) (1.7.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\thu hien\appdata\roaming\python\python39\site-packages (from packaging>=20.0->optuna) (2.4.7)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\thu hien\anaconda3\lib\site-packages (from sqlalchemy>=1.1.0->optuna) (1.1.1)
# Requirement already satisfied: Mako in c:\users\thu hien\anaconda3\lib\site-packages (from alembic->optuna) (1.2.0)
# Requirement already satisfied: PrettyTable>=0.7.2 in c:\users\thu hien\anaconda3\lib\site-packages (from cliff->optuna) (3.2.0)
# Requirement already satisfied: cmd2>=1.0.0 in c:\users\thu hien\anaconda3\lib\site-packages (from cliff->optuna) (2.4.1)
# Requirement already satisfied: autopage>=0.4.0 in c:\users\thu hien\anaconda3\lib\site-packages (from cliff->optuna) (0.5.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in c:\users\thu hien\anaconda3\lib\site-packages (from cliff->optuna) (5.8.1)
# Requirement already satisfied: stevedore>=2.0.1 in c:\users\thu hien\anaconda3\lib\site-packages (from cliff->optuna) (3.5.0)
# Requirement already satisfied: colorama in c:\users\thu hien\appdata\roaming\python\python39\site-packages (from colorlog->optuna) (0.4.4)
# Requirement already satisfied: pyperclip>=1.6 in c:\users\thu hien\anaconda3\lib\site-packages (from cmd2>=1.0.0->cliff->optuna) (1.8.2)
# Requirement already satisfied: pyreadline3 in c:\users\thu hien\anaconda3\lib\site-packages (from cmd2>=1.0.0->cliff->optuna) (3.4.1)
# Requirement already satisfied: attrs>=16.3.0 in c:\users\thu hien\appdata\roaming\python\python39\site-packages (from cmd2>=1.0.0->cliff->optuna) (21.2.0)
# Requirement already satisfied: wcwidth>=0.1.7 in c:\users\thu hien\appdata\roaming\python\python39\site-packages (from cmd2>=1.0.0->cliff->optuna) (0.2.5)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\thu hien\appdata\roaming\python\python39\site-packages (from Mako->alembic->optuna) (2.0.1)

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import os # accessing directory structure

# %%
dff = pd.read_csv("Life Expectancy Data.csv")
dff
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0                62     0.01               71.279624         65.0      1154
# 1                64     0.01               73.523582         62.0       492
# 2                66     0.01               73.219243         64.0       430
# 3                69     0.01               78.184215         67.0      2787
# 4                71     0.01                7.097109         68.0      3013
# ...             ...      ...                     ...          ...       ...
# 2933             27     4.36                0.000000         68.0        31
# 2934             26     4.06                0.000000          7.0       998
# 2935             25     4.43                0.000000         73.0       304
# 2936             25     1.72                0.000000         76.0       529
# 2937             24     1.68                0.000000         79.0      1483
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# 0     ...    6.0               8.16         65.0        0.1  584.259210
# 1     ...   58.0               8.18         62.0        0.1  612.696514
# 2     ...   62.0               8.13         64.0        0.1  631.744976
# 3     ...   67.0               8.52         67.0        0.1  669.959000
# 4     ...   68.0               7.87         68.0        0.1   63.537231
# ...   ...    ...                ...          ...        ...         ...
# 2933  ...   67.0               7.13         65.0       33.6  454.366654
# 2934  ...    7.0               6.52         68.0       36.7  453.351155
# 2935  ...   73.0               6.53         71.0       39.8   57.348340
# 2936  ...   76.0               6.16         75.0       42.1  548.587312
# 2937  ...   78.0               7.10         78.0       43.5  547.358878
#
#       Population   thinness  1-19 years   thinness 5-9 years  \
# 0     33736494.0                   17.2                 17.3
# 1       327582.0                   17.5                 17.5
# 2     31731688.0                   17.7                 17.7
# 3      3696958.0                   17.9                 18.0
# 4      2978599.0                   18.2                 18.2
# ...          ...                    ...                  ...
# 2933  12777511.0                    9.4                  9.4
# 2934  12633897.0                    9.8                  9.9
# 2935    125525.0                    1.2                  1.3
# 2936  12366165.0                    1.6                  1.7
# 2937  12222251.0                   11.0                 11.2
#
#       Income composition of resources  Schooling
# 0                               0.479       10.1
# 1                               0.476       10.0
# 2                               0.470        9.9
# 3                               0.463        9.8
# 4                               0.454        9.5
# ...                               ...        ...
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [2938 rows x 22 columns]

# %%
dx = pd.read_csv("X_train.csv")
dx.head()
# Out:
#                                          country  year      status  \
# 0  UnitedKingdomofGreatBritainandNorthernIreland  2009   Developed
# 1           TheformerYugoslavrepublicofMacedonia  2015  Developing
# 2                                RepublicofKorea  2012  Developing
# 3              DemocraticPeople'sRepublicofKorea  2011  Developing
# 4                                           Peru  2005  Developing
#
#    adult_mortality  infant_deaths  alcohol  percentage_expenditure  \
# 0             78.0              4    10.79                0.000000
# 1             12.0              0     4.60                0.000000
# 2             69.0              1     9.56                0.000000
# 3            153.0              8     3.39                0.000000
# 4            148.0             13     4.44              411.564565
#
#    hepatitis_b  measles   bmi  ...  polio  total_expenditure  diphtheria  \
# 0         81.0     1212  63.1  ...   93.0               9.81        93.0
# 1         92.0        1   6.3  ...   92.0               5.94        91.0
# 2         99.0        2   3.4  ...   99.0               7.10        99.0
# 3         94.0        0   3.8  ...   99.0               5.94        94.0
# 4         94.0        0  48.8  ...   66.0               4.72        77.0
#
#    hiv/aids          gdp  population  thinness_1_19_years  thinness_5_9_years  \
# 0       0.1  7483.158469  12753375.0                  0.8                 0.5
# 1       0.1  7483.158469  12753375.0                  2.1                 2.1
# 2       0.1  7483.158469  12753375.0                  1.5                 1.0
# 3       0.1  7483.158469  12753375.0                  5.1                 5.2
# 4       0.4  2754.782900    276141.0                  1.3                 1.3
#
#    income_composition_of_resources  schooling
# 0                            0.628       12.0
# 1                            0.746       12.9
# 2                            0.628       12.0
# 3                            0.628       12.0
# 4                            0.692       13.0
#
# [5 rows x 21 columns]

# %%
dy = pd.read_csv("y_train.csv")
dy.head()
# Out:
#    life_expectancy
# 0             81.0
# 1             75.7
# 2             81.2
# 3             69.4
# 4             72.8

# %%
from sklearn.linear_model import Ridge

ridge_reg = Ridge(alpha = 50, max_iter = 1000, tol = 0.1)
dxx = dx.drop(["country", "status"], axis = 1)
ridge_reg.fit( dxx, dy)
# Out:
# C:\Users\THU HIEN\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.07649e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# Ridge(alpha=50, max_iter=1000, tol=0.1)

# %%
ridge_reg.score(dxx, dy)
# Out:
# 0.8156967030438289

# %%
x_test = pd.read_csv("X_test.csv")
X_test = x_test.drop(["country", "status"], axis = 1)

# %%
y_test = pd.read_csv("y_test.csv")

# %%
y_pred = ridge_reg.predict(X_test)
y_pred
# Out:
# array([[76.56197611],
#        [76.10035097],
#        [77.09607349],
#        [70.15929801],
#        [81.07569394],
#        [72.53102287],
#        [73.53680652],
#        [72.58318443],
#        [76.93162612],
#        [74.88702493],
#        [74.52914081],
#        [56.94221937],
#        [72.02023423],
#        [69.26072818],
#        [75.41268982],
#        [73.2562546 ],
#        [51.42114203],
#        [61.12391642],
#        [61.37714264],
#        [63.02207211],
#        [67.36784388],
#        [43.37012814],
#        [73.22087091],
#        [70.5168261 ],
#        [55.59816698],
#        [58.09874042],
#        [76.2674615 ],
#        [60.06403533],
#        [74.32800871],
#        [71.9028729 ],
#        [72.62755841],
#        [77.15707478],
#        [70.67612464],
#        [77.02284635],
#        [71.56471218],
#        [67.42017023],
#        [76.65964613],
#        [74.76374305],
#        [67.5431697 ],
#        [76.44961892],
#        [77.84567771],
#        [77.05650592],
#        [76.43256088],
#        [61.58496965],
#        [77.30888091],
#        [68.90938056],
#        [75.46536584],
#        [62.95471498],
#        [62.23526832],
#        [58.60298746],
#        [66.64814677],
#        [64.81196803],
#        [58.38670466],
#        [70.7882646 ],
#        [69.94427981],
#        [68.73446185],
#        [72.32875207],
#        [51.20623431],
#        [74.73216161],
#        [68.52858504],
#        [74.4538543 ],
#        [74.90648956],
#        [70.9269799 ],
#        [70.18219023],
#        [71.66670975],
#        [68.14152644],
#        [63.91766239],
#        [78.38263948],
#        [68.08882214],
#        [68.34125671],
#        [80.4947811 ],
#        [54.04876761],
#        [71.66815422],
#        [52.92740288],
#        [76.27153694],
#        [77.04947501],
#        [67.82665493],
#        [50.39536478],
#        [64.55437216],
#        [75.25532247],
#        [59.64384014],
#        [75.03419118],
#        [79.79867416],
#        [74.99108946],
#        [76.8473968 ],
#        [66.55825197],
#        [69.77313336],
#        [70.29367489],
#        [66.40779123],
#        [75.62448887],
#        [78.85435124],
#        [63.37364739],
#        [65.58529564],
#        [79.75420015],
#        [69.68392298],
#        [60.98973681],
#        [61.84006077],
#        [68.00654674],
#        [63.17244183],
#        [59.31968327],
#        [67.42600388],
#        [60.06520729],
#        [74.03327189],
#        [57.85062748],
#        [69.89533408],
#        [73.83147866],
#        [49.84165989],
#        [77.41681173],
#        [77.16593088],
#        [67.54635834],
#        [76.29918421],
#        [71.34754907],


# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.8102071028322755

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (15,10))
plt.scatter(y_test, y_pred)
plt.xlabel('Actual')
plt.ylabel('predicted')
# Out:
# Text(0, 0.5, 'predicted')

# %%
import pandas as pd
from seaborn import heatmap

# %%
f, ax = plt.subplots(1, 1, figsize=(20, 20))
ax = sns.heatmap(dff.corr(), annot=True, cmap='coolwarm')

# %%
n = len(y_test)
mse = y_test - y_pred
mse = mse ** 2
mse = np.sum(mse)
mse = mse / n
print('Mean Squared Error :', mse)
# Out:
# Mean Squared Error : life_expectancy    17.526109
# dtype: float64

# %% [markdown]
# # Eliminate some columns

# %%
X_test.head()
# Out:
#    year  adult_mortality  infant_deaths  alcohol  percentage_expenditure  \
# 0  2009             12.0              0    13.23                0.000000
# 1  2000             13.0              2     6.24               74.148429
# 2  2007            176.0              1    12.55              163.343328
# 3  2002            167.0              1     3.76              211.114332
# 4  2003             95.0              0    11.28              507.306164
#
#    hepatitis_b  measles   bmi  under_five_deaths  polio  total_expenditure  \
# 0         99.0        5  63.1                  0   99.0               7.85
# 1         81.0        0  54.0                  3   91.0               6.40
# 2         81.0        0  59.9                  1   99.0               7.51
# 3         81.0        0  43.5                  1   99.0               4.86
# 4         64.0       44  59.4                  1   96.0               9.30
#
#    diphtheria  hiv/aids           gdp  population  thinness_1_19_years  \
# 0        99.0       0.1   7483.158469  12753375.0                  1.9
# 1        91.0       0.1    511.368479  15262754.0                  1.1
# 2        99.0       0.1  13842.654900     15578.0                  1.9
# 3        99.0       2.3   3596.496282   2695446.0                  2.0
# 4        95.0       0.1   3743.956930   1376133.0                  0.8
#
#    thinness_5_9_years  income_composition_of_resources  schooling
# 0                 2.0                            0.628       12.0
# 1                 1.1                            0.755       13.5
# 2                 1.9                            0.809       15.3
# 3                 1.8                            0.690       11.7
# 4                 0.8                            0.878       18.6

# %%
X_test2 = X_test.drop(['thinness_1_19_years'], axis = 1)
ridge_reg2 = Ridge(alpha = 50, max_iter = 1000, tol = 0.1)
dx3 = dxx.drop(['thinness_1_19_years'], axis = 1)
ridge_reg2.fit( dx3, dy)
# Out:
# C:\Users\THU HIEN\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.07706e-17): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# Ridge(alpha=50, max_iter=1000, tol=0.1)

# %%
y_pred2 = ridge_reg2.predict(X_test2)

# %%
ridge_reg2.score(dx3, dy)
# Out:
# 0.8154220923808836

# %%
r2_score(y_test, y_pred2)
# Out:
# 0.8102239558485629

# %% [markdown]
# # Outlier detecting

# %%
df = pd.concat([dy, y_test])
df
# Out:
#      life_expectancy
# 0               81.0
# 1               75.7
# 2               81.2
# 3               69.4
# 4               72.8
# ..               ...
# 877             62.4
# 878             73.8
# 879             79.4
# 880             82.5
# 881             68.0
#
# [2938 rows x 1 columns]

# %%
df.life_expectancy.describe()
# Out:
# count    2938.000000
# mean       69.224847
# std         9.507640
# min        36.300000
# 25%        63.200000
# 50%        72.000000
# 75%        75.600000
# max        89.000000
# Name: life_expectancy, dtype: float64

# %%
from scipy.stats import norm
plt.hist(dy, bins = 20, rwidth = 0.8, density = True)
plt.xlabel("Life expectancy")
plt.ylabel("Count")

rng = np.arange(df.life_expectancy.min(),df.life_expectancy.max(), 0.1)
plt.plot(rng, norm.pdf(rng, df.life_expectancy.mean(),df.life_expectancy.std()))

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))
df[["life_expectancy"]].hist(bins=50, ax=axes[0]);
df[["life_expectancy"]].boxplot(ax=axes[1], vert=False);

# %%
from typing import Tuple
from sklearn.base import BaseEstimator, TransformerMixin


def find_boxplot_boundaries(
    col: pd.Series, whisker_coeff: float = 1
) -> Tuple[float, float]:
    """Findx minimum and maximum in boxplot.

    Args:
        col: a pandas serires of input.
        whisker_coeff: whisker coefficient in box plot
    """
    Q1 = col.quantile(0.25)
    Q3 = col.quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - whisker_coeff * IQR
    upper = Q3 + whisker_coeff * IQR
    return lower, upper

class BoxplotOutlierClipper(BaseEstimator, TransformerMixin):
    def __init__(self, whisker_coeff: float = 1.5):
        self.whisker = whisker_coeff
        self.lower = None
        self.upper = None

    def fit(self, X: pd.Series):
        self.lower, self.upper = find_boxplot_boundaries(X, self.whisker)
        return self

    def transform(self, X):
        return X.clip(self.lower, self.upper)

# %%
def outlier_eliminate(X_train, X_test, y_train, y_test, lower, upper):
    train = pd.concat([X_train, y_train], axis=1)
    test = pd.concat([X_test, y_test], axis=1)
    train_no_outlier = train[(train.life_expectancy > lower)&(train.life_expectancy < upper)]
    test_no_outlier = test[(test.life_expectancy > lower)&(test.life_expectancy < upper)]
    
    X_train_no_outlier = train_no_outlier.drop(["life_expectancy"], axis = 1)
    y_train_no_outlier = train_no_outlier["life_expectancy"]
    X_test_no_outlier  = test_no_outlier.drop(["life_expectancy"], axis = 1)
    y_test_no_outlier = test_no_outlier["life_expectancy"]
    
    return X_train_no_outlier, y_train_no_outlier, X_test_no_outlier, y_test_no_outlier

# %%
df_no_outlier = BoxplotOutlierClipper().fit_transform(df["life_expectancy"])

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))
df_no_outlier.hist(bins=50, ax=axes[0])
df_no_outlier.to_frame().boxplot(ax=axes[1], vert=False);

# %%
lower, upper = find_boxplot_boundaries(df["life_expectancy"], 1.5)
lower, upper
# Out:
# (44.600000000000016, 94.19999999999999)

# %%
X_train_no_outlier, y_train_no_outlier, X_test_no_outlier, y_test_no_outlier = outlier_eliminate(dx3, X_test2, dy, y_test, lower, upper)

# %%
y_pred3 = ridge_reg2.predict(X_test_no_outlier)

# %%
ridge_reg2.score(X_train_no_outlier, y_train_no_outlier)
# Out:
# 0.816444377325851

# %%
r2_score(y_test_no_outlier, y_pred3)
# Out:
# 0.8156092720598214

# %% [markdown]
# # Hyperparameter Tuning

# %%
import optuna
import sklearn.model_selection

# %%
# 1. Define an objective function to be maximized.
def objective(trial):
    x = pd.concat([X_train_no_outlier, X_test_no_outlier])
    y = pd.concat([y_train_no_outlier,  y_test_no_outlier])

    # 2. Suggest values for the hyperparameters using a trial object.

    r_alpha = trial.suggest_float('r_alpha', 1, 100, log=True)
    r_max_iter =  trial.suggest_int('r_max_iter', 1000, 1000000, log=True)
    Ridge_obj = Ridge(alpha=r_alpha, max_iter=r_max_iter, tol = 0.01)
    
    score = sklearn.model_selection.cross_val_score(Ridge_obj, x, y, n_jobs=-1, cv=3)
    accuracy = score.mean()
    return accuracy

# %%
# 3. Create a study object and optimize the objective function.
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=100)
study.best_trial
# Out:
# [I 2022-05-03 13:29:30,566] A new study created in memory with name: no-name-6dd1d753-4a4c-4e53-8848-f49d67be5a68
# [I 2022-05-03 13:29:33,257] Trial 0 finished with value: 0.810727377644548 and parameters: {'r_alpha': 55.72363099660616, 'r_max_iter': 94166}. Best is trial 0 with value: 0.810727377644548.
# [I 2022-05-03 13:29:34,153] Trial 1 finished with value: 0.8132798845713022 and parameters: {'r_alpha': 5.424517567416762, 'r_max_iter': 5040}. Best is trial 1 with value: 0.8132798845713022.
# [I 2022-05-03 13:29:35,075] Trial 2 finished with value: 0.8116387015559828 and parameters: {'r_alpha': 32.724900078563465, 'r_max_iter': 501498}. Best is trial 1 with value: 0.8132798845713022.
# [I 2022-05-03 13:29:35,128] Trial 3 finished with value: 0.8134323104812906 and parameters: {'r_alpha': 1.3417004391215515, 'r_max_iter': 52516}. Best is trial 3 with value: 0.8134323104812906.
# [I 2022-05-03 13:29:35,170] Trial 4 finished with value: 0.8133257026567088 and parameters: {'r_alpha': 4.496858605346013, 'r_max_iter': 170244}. Best is trial 3 with value: 0.8134323104812906.
# [I 2022-05-03 13:29:35,211] Trial 5 finished with value: 0.8130880180693417 and parameters: {'r_alpha': 8.725271561359587, 'r_max_iter': 17541}. Best is trial 3 with value: 0.8134323104812906.
# [I 2022-05-03 13:29:35,251] Trial 6 finished with value: 0.8102676903671812 and parameters: {'r_alpha': 72.72923966046372, 'r_max_iter': 1687}. Best is trial 3 with value: 0.8134323104812906.
# [I 2022-05-03 13:29:35,293] Trial 7 finished with value: 0.8134200500151167 and parameters: {'r_alpha': 1.9266832678167571, 'r_max_iter': 64726}. Best is trial 3 with value: 0.8134323104812906.
# [I 2022-05-03 13:29:35,334] Trial 8 finished with value: 0.8101778310059631 and parameters: {'r_alpha': 76.72268316354662, 'r_max_iter': 138534}. Best is trial 3 with value: 0.8134323104812906.
# [I 2022-05-03 13:29:35,375] Trial 9 finished with value: 0.8133711355932713 and parameters: {'r_alpha': 3.442685916630327, 'r_max_iter': 8656}. Best is trial 3 with value: 0.8134323104812906.
# [I 2022-05-03 13:29:35,425] Trial 10 finished with value: 0.8134366537768879 and parameters: {'r_alpha': 1.0591182335830358, 'r_max_iter': 917350}. Best is trial 10 with value: 0.8134366537768879.
# [I 2022-05-03 13:29:35,460] Trial 11 finished with value: 0.8134346103283496 and parameters: {'r_alpha': 1.2009082196750316, 'r_max_iter': 931940}. Best is trial 10 with value: 0.8134366537768879.
# [I 2022-05-03 13:29:35,484] Trial 12 finished with value: 0.8134368689263504 and parameters: {'r_alpha': 1.0429560557143465, 'r_max_iter': 919629}. Best is trial 12 with value: 0.8134368689263504.
# [I 2022-05-03 13:29:35,513] Trial 13 finished with value: 0.8122294584795414 and parameters: {'r_alpha': 22.00468087618117, 'r_max_iter': 378421}. Best is trial 12 with value: 0.8134368689263504.
# [I 2022-05-03 13:29:35,537] Trial 14 finished with value: 0.8134012015130593 and parameters: {'r_alpha': 2.596389962202492, 'r_max_iter': 800387}. Best is trial 12 with value: 0.8134368689263504.
# [I 2022-05-03 13:29:35,570] Trial 15 finished with value: 0.8134372911123523 and parameters: {'r_alpha': 1.0103992593215119, 'r_max_iter': 310747}. Best is trial 15 with value: 0.8134372911123523.
# [I 2022-05-03 13:29:35,594] Trial 16 finished with value: 0.8126279292980331 and parameters: {'r_alpha': 15.733843699340213, 'r_max_iter': 248430}. Best is trial 15 with value: 0.8134372911123523.
# [I 2022-05-03 13:29:35,620] Trial 17 finished with value: 0.8134152343674126 and parameters: {'r_alpha': 2.1151522281413744, 'r_max_iter': 27710}. Best is trial 15 with value: 0.8134372911123523.
# [I 2022-05-03 13:29:35,653] Trial 18 finished with value: 0.8131606476484935 and parameters: {'r_alpha': 7.542630494333284, 'r_max_iter': 328486}. Best is trial 15 with value: 0.8134372911123523.
# [I 2022-05-03 13:29:35,685] Trial 19 finished with value: 0.8134232135708714 and parameters: {'r_alpha': 1.7932360571051866, 'r_max_iter': 204501}. Best is trial 15 with value: 0.8134372911123523.
# [I 2022-05-03 13:29:35,712] Trial 20 finished with value: 0.8133718403756077 and parameters: {'r_alpha': 3.4246644921705918, 'r_max_iter': 517777}. Best is trial 15 with value: 0.8134372911123523.
# [I 2022-05-03 13:29:35,738] Trial 21 finished with value: 0.8134358210929973 and parameters: {'r_alpha': 1.119254857599162, 'r_max_iter': 984655}. Best is trial 15 with value: 0.8134372911123523.
# [I 2022-05-03 13:29:35,770] Trial 22 finished with value: 0.8134359151063585 and parameters: {'r_alpha': 1.1126433170495915, 'r_max_iter': 497412}. Best is trial 15 with value: 0.8134372911123523.
# [I 2022-05-03 13:29:35,794] Trial 23 finished with value: 0.8134286012381998 and parameters: {'r_alpha': 1.5414589885018046, 'r_max_iter': 607909}. Best is trial 15 with value: 0.8134372911123523.
# [I 2022-05-03 13:29:35,820] Trial 24 finished with value: 0.8134372357586849 and parameters: {'r_alpha': 1.0147347410521401, 'r_max_iter': 296245}. Best is trial 15 with value: 0.8134372911123523.
# [I 2022-05-03 13:29:35,845] Trial 25 finished with value: 0.8134021722985164 and parameters: {'r_alpha': 2.565540920521221, 'r_max_iter': 113109}. Best is trial 15 with value: 0.8134372911123523.
# [I 2022-05-03 13:29:35,871] Trial 26 finished with value: 0.8134374054507506 and parameters: {'r_alpha': 1.0013767598853578, 'r_max_iter': 274777}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:35,895] Trial 27 finished with value: 0.8127439461068406 and parameters: {'r_alpha': 13.980616665924996, 'r_max_iter': 63788}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:35,929] Trial 28 finished with value: 0.8134275340705401 and parameters: {'r_alpha': 1.59435122213525, 'r_max_iter': 241474}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:35,954] Trial 29 finished with value: 0.8133970159339191 and parameters: {'r_alpha': 2.7261597460561298, 'r_max_iter': 98425}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:35,978] Trial 30 finished with value: 0.8132502952161119 and parameters: {'r_alpha': 5.980683696309841, 'r_max_iter': 29190}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:36,002] Trial 31 finished with value: 0.8134286825716615 and parameters: {'r_alpha': 1.5373551837634, 'r_max_iter': 338304}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:36,030] Trial 32 finished with value: 0.8134371280047507 and parameters: {'r_alpha': 1.0231151199844997, 'r_max_iter': 328636}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:36,063] Trial 33 finished with value: 0.8113251800590201 and parameters: {'r_alpha': 39.50452600821596, 'r_max_iter': 150027}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:36,089] Trial 34 finished with value: 0.8134177816587679 and parameters: {'r_alpha': 2.017414234332452, 'r_max_iter': 290811}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:36,113] Trial 35 finished with value: 0.8134310914656372 and parameters: {'r_alpha': 1.4104805639629447, 'r_max_iter': 94225}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:36,137] Trial 36 finished with value: 0.8133610349856593 and parameters: {'r_alpha': 3.69409915437385, 'r_max_iter': 40070}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:36,169] Trial 37 finished with value: 0.8134317435265382 and parameters: {'r_alpha': 1.3741243108535437, 'r_max_iter': 178023}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:36,195] Trial 38 finished with value: 0.8134373661378705 and parameters: {'r_alpha': 1.004489290864015, 'r_max_iter': 13189}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:36,219] Trial 39 finished with value: 0.8134108545146846 and parameters: {'r_alpha': 2.2745789792653928, 'r_max_iter': 9275}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:36,251] Trial 40 finished with value: 0.8098032338794426 and parameters: {'r_alpha': 96.71581333200848, 'r_max_iter': 2637}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:36,270] Trial 41 finished with value: 0.8134317344853791 and parameters: {'r_alpha': 1.3746350647311079, 'r_max_iter': 10830}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:36,303] Trial 42 finished with value: 0.8134364995000363 and parameters: {'r_alpha': 1.0705411383994443, 'r_max_iter': 17299}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:36,336] Trial 43 finished with value: 0.8134239997256065 and parameters: {'r_alpha': 1.7586287873041566, 'r_max_iter': 4187}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:36,379] Trial 44 finished with value: 0.8134333362951619 and parameters: {'r_alpha': 1.2808941773193239, 'r_max_iter': 15039}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:36,411] Trial 45 finished with value: 0.8134244665811226 and parameters: {'r_alpha': 1.7377730221047816, 'r_max_iter': 443295}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:36,439] Trial 46 finished with value: 0.813437253245437 and parameters: {'r_alpha': 1.0133673797132428, 'r_max_iter': 6532}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:36,466] Trial 47 finished with value: 0.8134373918782986 and parameters: {'r_alpha': 1.002452571454201, 'r_max_iter': 5534}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:36,486] Trial 48 finished with value: 0.8133903065666424 and parameters: {'r_alpha': 2.9245816075454485, 'r_max_iter': 3887}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:36,519] Trial 49 finished with value: 0.8133250402587082 and parameters: {'r_alpha': 4.511029979282804, 'r_max_iter': 6453}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:36,544] Trial 50 finished with value: 0.8134335156219182 and parameters: {'r_alpha': 1.2699547644411306, 'r_max_iter': 1465}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:36,581] Trial 51 finished with value: 0.8134336739503079 and parameters: {'r_alpha': 1.2602140140867362, 'r_max_iter': 5803}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:36,624] Trial 52 finished with value: 0.8134188328710064 and parameters: {'r_alpha': 1.9758326649743871, 'r_max_iter': 11677}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:36,682] Trial 53 finished with value: 0.813437090881307 and parameters: {'r_alpha': 1.0259845276770474, 'r_max_iter': 2132}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:36,734] Trial 54 finished with value: 0.8134277304405803 and parameters: {'r_alpha': 1.5847471724012563, 'r_max_iter': 1110}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:36,794] Trial 55 finished with value: 0.813437098687011 and parameters: {'r_alpha': 1.0253819442683865, 'r_max_iter': 21652}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:36,855] Trial 56 finished with value: 0.8134109258125108 and parameters: {'r_alpha': 2.2720610472923193, 'r_max_iter': 7797}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:36,912] Trial 57 finished with value: 0.8134340484194663 and parameters: {'r_alpha': 1.2368561450484818, 'r_max_iter': 3109}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:36,970] Trial 58 finished with value: 0.8134305625275026 and parameters: {'r_alpha': 1.4392927791278545, 'r_max_iter': 51300}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:37,011] Trial 59 finished with value: 0.813434077190827 and parameters: {'r_alpha': 1.235042315995676, 'r_max_iter': 4825}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:37,051] Trial 60 finished with value: 0.8134233238221857 and parameters: {'r_alpha': 1.7884202917833876, 'r_max_iter': 667446}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:37,092] Trial 61 finished with value: 0.8134373017372684 and parameters: {'r_alpha': 1.0095646787261463, 'r_max_iter': 248016}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:37,131] Trial 62 finished with value: 0.8134373171051185 and parameters: {'r_alpha': 1.0083561643648757, 'r_max_iter': 226382}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:37,162] Trial 63 finished with value: 0.8134354690384397 and parameters: {'r_alpha': 1.143645066169321, 'r_max_iter': 248704}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:37,195] Trial 64 finished with value: 0.8128604451933054 and parameters: {'r_alpha': 12.227104523291713, 'r_max_iter': 127397}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:37,222] Trial 65 finished with value: 0.8134280136104728 and parameters: {'r_alpha': 1.5707978028073728, 'r_max_iter': 205689}. Best is trial 26 with value: 0.8134374054507506.
# [I 2022-05-03 13:29:37,255] Trial 66 finished with value: 0.8134374092737741 and parameters: {'r_alpha': 1.0010734942382078, 'r_max_iter': 421977}. Best is trial 66 with value: 0.8134374092737741.
# [I 2022-05-03 13:29:37,287] Trial 67 finished with value: 0.8134344793994356 and parameters: {'r_alpha': 1.2093853856411745, 'r_max_iter': 403111}. Best is trial 66 with value: 0.8134374092737741.
# [I 2022-05-03 13:29:37,312] Trial 68 finished with value: 0.8134299830811594 and parameters: {'r_alpha': 1.4702084943271085, 'r_max_iter': 712910}. Best is trial 66 with value: 0.8134374092737741.
# [I 2022-05-03 13:29:37,354] Trial 69 finished with value: 0.8116087608818577 and parameters: {'r_alpha': 33.33335259274232, 'r_max_iter': 566625}. Best is trial 66 with value: 0.8134374092737741.
# [I 2022-05-03 13:29:37,411] Trial 70 finished with value: 0.8134352885190027 and parameters: {'r_alpha': 1.1559358227193122, 'r_max_iter': 186521}. Best is trial 66 with value: 0.8134374092737741.
# [I 2022-05-03 13:29:37,464] Trial 71 finished with value: 0.8134367197831915 and parameters: {'r_alpha': 1.054189084306967, 'r_max_iter': 7486}. Best is trial 66 with value: 0.8134374092737741.
# [I 2022-05-03 13:29:37,508] Trial 72 finished with value: 0.8134374052003475 and parameters: {'r_alpha': 1.0013966197804995, 'r_max_iter': 452585}. Best is trial 66 with value: 0.8134374092737741.
# [I 2022-05-03 13:29:37,561] Trial 73 finished with value: 0.8134323562001633 and parameters: {'r_alpha': 1.3390508675191324, 'r_max_iter': 455463}. Best is trial 66 with value: 0.8134374092737741.
# [I 2022-05-03 13:29:37,611] Trial 74 finished with value: 0.8134350219074017 and parameters: {'r_alpha': 1.1738353401380366, 'r_max_iter': 274419}. Best is trial 66 with value: 0.8134374092737741.
# [I 2022-05-03 13:29:37,644] Trial 75 finished with value: 0.8134269204997344 and parameters: {'r_alpha': 1.6240063670257736, 'r_max_iter': 385260}. Best is trial 66 with value: 0.8134374092737741.
# [I 2022-05-03 13:29:37,669] Trial 76 finished with value: 0.8134140753811935 and parameters: {'r_alpha': 2.1583302389603882, 'r_max_iter': 231888}. Best is trial 66 with value: 0.8134374092737741.
# [I 2022-05-03 13:29:37,702] Trial 77 finished with value: 0.8107669487244179 and parameters: {'r_alpha': 54.47728478810358, 'r_max_iter': 79897}. Best is trial 66 with value: 0.8134374092737741.
# [I 2022-05-03 13:29:37,726] Trial 78 finished with value: 0.813421185832785 and parameters: {'r_alpha': 1.8797707963305352, 'r_max_iter': 164282}. Best is trial 66 with value: 0.8134374092737741.
# [I 2022-05-03 13:29:37,758] Trial 79 finished with value: 0.8134313998429281 and parameters: {'r_alpha': 1.3934062191372252, 'r_max_iter': 779814}. Best is trial 66 with value: 0.8134374092737741.
# [I 2022-05-03 13:29:37,789] Trial 80 finished with value: 0.8131352238670239 and parameters: {'r_alpha': 7.962833587362177, 'r_max_iter': 558508}. Best is trial 66 with value: 0.8134374092737741.
# [I 2022-05-03 13:29:37,813] Trial 81 finished with value: 0.8123531900175677 and parameters: {'r_alpha': 19.999900647407387, 'r_max_iter': 357211}. Best is trial 66 with value: 0.8134374092737741.
# [I 2022-05-03 13:29:37,841] Trial 82 finished with value: 0.8134374084667712 and parameters: {'r_alpha': 1.0011375193364216, 'r_max_iter': 14604}. Best is trial 66 with value: 0.8134374092737741.
# [I 2022-05-03 13:29:37,873] Trial 83 finished with value: 0.8134354453775833 and parameters: {'r_alpha': 1.145264130244961, 'r_max_iter': 12690}. Best is trial 66 with value: 0.8134374092737741.
# [I 2022-05-03 13:29:37,897] Trial 84 finished with value: 0.8134370437727728 and parameters: {'r_alpha': 1.0296128111142053, 'r_max_iter': 25048}. Best is trial 66 with value: 0.8134374092737741.
# [I 2022-05-03 13:29:37,937] Trial 85 finished with value: 0.813431971906932 and parameters: {'r_alpha': 1.3611580178314222, 'r_max_iter': 40293}. Best is trial 66 with value: 0.8134374092737741.
# [I 2022-05-03 13:29:37,974] Trial 86 finished with value: 0.8134348376556019 and parameters: {'r_alpha': 1.1860365516563809, 'r_max_iter': 20356}. Best is trial 66 with value: 0.8134374092737741.
# [I 2022-05-03 13:29:38,006] Trial 87 finished with value: 0.8134372226585754 and parameters: {'r_alpha': 1.01575773448014, 'r_max_iter': 292163}. Best is trial 66 with value: 0.8134374092737741.
# [I 2022-05-03 13:29:38,037] Trial 88 finished with value: 0.8134270002016732 and parameters: {'r_alpha': 1.620183742392332, 'r_max_iter': 9578}. Best is trial 66 with value: 0.8134374092737741.
# [I 2022-05-03 13:29:38,060] Trial 89 finished with value: 0.8134329523952815 and parameters: {'r_alpha': 1.3039929746646164, 'r_max_iter': 14244}. Best is trial 66 with value: 0.8134374092737741.
# [I 2022-05-03 13:29:38,088] Trial 90 finished with value: 0.8134355792876452 and parameters: {'r_alpha': 1.1360680471657083, 'r_max_iter': 146057}. Best is trial 66 with value: 0.8134374092737741.
# [I 2022-05-03 13:29:38,117] Trial 91 finished with value: 0.8134373866454574 and parameters: {'r_alpha': 1.002867000502603, 'r_max_iter': 6278}. Best is trial 66 with value: 0.8134374092737741.
# [I 2022-05-03 13:29:38,151] Trial 92 finished with value: 0.8134293350034895 and parameters: {'r_alpha': 1.5040387270647504, 'r_max_iter': 5441}. Best is trial 66 with value: 0.8134374092737741.
# [I 2022-05-03 13:29:38,178] Trial 93 finished with value: 0.8134373954584323 and parameters: {'r_alpha': 1.0021689213639333, 'r_max_iter': 3348}. Best is trial 66 with value: 0.8134374092737741.
# [I 2022-05-03 13:29:38,204] Trial 94 finished with value: 0.8134358902520763 and parameters: {'r_alpha': 1.1143953633292454, 'r_max_iter': 3292}. Best is trial 66 with value: 0.8134374092737741.
# [I 2022-05-03 13:29:38,243] Trial 95 finished with value: 0.8134329768876296 and parameters: {'r_alpha': 1.3025319631584078, 'r_max_iter': 2236}. Best is trial 66 with value: 0.8134374092737741.
# [I 2022-05-03 13:29:38,268] Trial 96 finished with value: 0.8134357825051709 and parameters: {'r_alpha': 1.1219562955557765, 'r_max_iter': 3297}. Best is trial 66 with value: 0.8134374092737741.
# [I 2022-05-03 13:29:38,301] Trial 97 finished with value: 0.8134373067804387 and parameters: {'r_alpha': 1.0091682682617868, 'r_max_iter': 3782}. Best is trial 66 with value: 0.8134374092737741.
# [I 2022-05-03 13:29:38,325] Trial 98 finished with value: 0.8134307312688357 and parameters: {'r_alpha': 1.4301643616111046, 'r_max_iter': 4582}. Best is trial 66 with value: 0.8134374092737741.
# [I 2022-05-03 13:29:38,350] Trial 99 finished with value: 0.813425008702521 and parameters: {'r_alpha': 1.7132560598529352, 'r_max_iter': 3742}. Best is trial 66 with value: 0.8134374092737741.
# FrozenTrial(number=66, values=[0.8134374092737741], datetime_start=datetime.datetime(2022, 5, 3, 13, 29, 37, 222707), datetime_complete=datetime.datetime(2022, 5, 3, 13, 29, 37, 255010), params={'r_alpha': 1.0010734942382078, 'r_max_iter': 421977}, distributions={'r_alpha': LogUniformDistribution(high=100.0, low=1.0), 'r_max_iter': IntLogUniformDistribution(high=1000000, low=1000, step=1)}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=66, state=TrialState.COMPLETE, value=None)

# %%
ridge_reg3 = Ridge(alpha =1.0010734942382078, max_iter =  421977, tol = 0.01)
ridge_reg3.fit(X_train_no_outlier , y_train_no_outlier)
# Out:
# C:\Users\THU HIEN\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=3.95121e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,
# Ridge(alpha=1.0010734942382078, max_iter=421977, tol=0.01)

# %%
ridge_reg3.score(X_train_no_outlier, y_train_no_outlier)
# Out:
# 0.8166713482266807

# %%
r2_score(y_test_no_outlier, y_pred3)
# Out:
# 0.8156092720598214

# %% [markdown]
# # Principal Component Analysis (PCA)

# %%
feature_not_required = []

# %%
X_train_no_outlier.adult_mortality = X_train_no_outlier.apply(lambda x: np.nan if (x.adult_mortality < 35 or x.adult_mortality > 600) else x.adult_mortality, axis=1)
X_train_no_outlier.infant_deaths = X_train_no_outlier.apply(lambda x: np.nan if (x.infant_deaths < 2 or x.infant_deaths > 900) else x.infant_deaths, axis=1)
X_train_no_outlier.bmi = X_train_no_outlier.apply(lambda x: np.nan if (x.bmi < 18 or x.bmi > 33) else x.bmi, axis=1)
X_train_no_outlier.under_five_deaths = X_train_no_outlier.apply(lambda x: np.nan if (x.under_five_deaths < 3 or x.under_five_deaths > 800) else x.under_five_deaths, axis=1)

# %%
X_test_no_outlier.adult_mortality = X_test_no_outlier.apply(lambda x: np.nan if (x.adult_mortality < 35 or x.adult_mortality > 600) else x.adult_mortality, axis=1)
X_test_no_outlier.infant_deaths = X_test_no_outlier.apply(lambda x: np.nan if (x.infant_deaths < 2 or x.infant_deaths > 900) else x.infant_deaths, axis=1)
X_test_no_outlier.bmi = X_test_no_outlier.apply(lambda x: np.nan if (x.bmi < 18 or x.bmi > 33) else x.bmi, axis=1)
X_test_no_outlier.under_five_deaths = X_test_no_outlier.apply(lambda x: np.nan if (x.under_five_deaths < 3 or x.under_five_deaths > 800) else x.under_five_deaths, axis=1)

# %%
sns.set(style='whitegrid')
f,ax = plt.subplots(1,1,figsize = (8,4))
ax = sns.distplot(df['life_expectancy'], kde = True, color = 'c')
# Out:
# C:\Users\THU HIEN\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
feature_not_required.append('infant_deaths')
feature_not_required.append('alcohol')
feature_not_required.append('percentage_expenditure')
feature_not_required.append('hepatitis_b')
feature_not_required.append('polio')
feature_not_required.append('total_expenditure')
feature_not_required.append('diphtheria')
feature_not_required.append('gdp')
feature_not_required.append('population')
feature_not_required.append('thinness_5_9_years')
feature_not_required.append('bmi')

# %%
feature_not_required
# Out:
# ['infant_deaths',
#  'alcohol',
#  'percentage_expenditure',
#  'hepatitis_b',
#  'polio',
#  'total_expenditure',
#  'diphtheria',
#  'gdp',
#  'population',
#  'thinness_5_9_years',
#  'bmi',
#  'infant_deaths',
#  'alcohol',
#  'percentage_expenditure',
#  'hepatitis_b',
#  'polio',
#  'total_expenditure',
#  'diphtheria',
#  'gdp',
#  'population',
#  'thinness_5_9_years',
#  'bmi']

# %%
X_train_final = X_train_no_outlier.drop(feature_not_required,axis=1)
X_test_final = X_test_no_outlier.drop(feature_not_required,axis=1)
X = pd.concat([X_train_final ,X_test_final ], axis = 1)

# %%
f, ax = plt.subplots(1, 1, figsize=(20, 20))
ax = sns.heatmap(X.corr(), annot=True, cmap='coolwarm')

# %%
X_train_final.drop(['under_five_deaths'],axis=1)
X_test_final.drop(['under_five_deaths'],axis=1)
# Out:
#      year  adult_mortality  measles  hiv/aids  \
# 0    2009        182.83776        5       0.1
# 1    2000        182.83776        0       0.1
# 2    2007        176.00000        0       0.1
# 3    2002        167.00000        0       2.3
# 4    2003         95.00000       44       0.1
# ..    ...              ...      ...       ...
# 877  2013        281.00000       12       0.8
# 878  2006        182.83776        0       0.1
# 879  2006         79.00000       28       0.1
# 880  2012         59.00000       42       0.1
# 881  2003        223.00000        0       1.0
#
#      income_composition_of_resources  schooling
# 0                              0.628       12.0
# 1                              0.755       13.5
# 2                              0.809       15.3
# 3                              0.690       11.7
# 4                              0.878       18.6
# ..                               ...        ...
# 877                            0.506       10.0
# 878                            0.751       13.2
# 879                            0.628       12.0
# 880                            0.917       15.4
# 881                            0.000       10.9
#
# [876 rows x 6 columns]

# %%
X_train_final.fillna(X.mean(), inplace=True)
X_test_final.fillna(X.mean(), inplace=True)

# %%
ridge_reg4 = Ridge(alpha =1.0010734942382078, max_iter =  421977, tol = 0.01)
ridge_reg4.fit(X_train_final , y_train_no_outlier)
# Out:
# Ridge(alpha=1.0010734942382078, max_iter=421977, tol=0.01)

# %%
ridge_reg4.score(X_train_final, y_train_no_outlier)
# Out:
# 0.7913884643225665
